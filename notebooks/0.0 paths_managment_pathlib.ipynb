# %%
import pathlib

# %%
CURRENT_DIR = pathlib.Path().resolve()
DATA_DIR = CURRENT_DIR.parent.joinpath("data","raw")

DATA_DIR.is_dir()
DATA_DIR.exists()
# Out:
# True

# %%
DATA_DIR.joinpath("pathlib").mkdir()

# %%
list(DATA_DIR.glob("*"))
# Out:
# [WindowsPath('C:/manejo_de_rutas/data/raw/.gitkeep'),
#  WindowsPath('C:/manejo_de_rutas/data/raw/os'),
#  WindowsPath('C:/manejo_de_rutas/data/raw/pathlib')]

# %%
list(DATA_DIR.glob(".git*"))
# Out:
# [WindowsPath('C:/manejo_de_rutas/data/raw/.gitkeep')]
